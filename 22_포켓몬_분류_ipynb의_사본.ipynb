# %%
# kaggle datasets download -d thedagger/pokemon-generation-one
# kaggle datasets download -d hlrhegemony/pokemon-image-dataset

# %% [markdown]
# # 1. 포켓몬 분류
# * Train: https://www.kaggle.com/datasets/thedagger/pokemon-generation-one
# * Validation: https://www.kaggle.com/hlrhegemony/pokemon-image-dataset

# %%
import os

os.environ['KAGGLE_USERNAME'] = 'mungiyang'
os.environ['KAGGLE_KEY'] = '87b8ef90a4b0811595aaa35ae0831a12'

# %%
# !kaggle datasets download -d thedagger/pokemon-generation-one
# !kaggle datasets download -d hlrhegemony/pokemon-image-dataset
# Out:
# Downloading pokemon-generation-one.zip to /content
#  99% 2.13G/2.15G [00:18<00:00, 76.3MB/s]
# 100% 2.15G/2.15G [00:18<00:00, 123MB/s]
# Downloading pokemon-image-dataset.zip to /content
#  97% 56.0M/57.9M [00:00<00:00, 172MB/s]
# 100% 57.9M/57.9M [00:00<00:00, 175MB/s]

# %%
# !unzip -q pokemon-generation-one.zip

# %%
# !unzip -q pokemon-image-dataset.zip

# %%
# !mv dataset train

# %%
# !rm -rf train/dataset # 데이터가 중복되어 있음 -> 삭제

# %%
# !mv images validation

# %%
train_labels = os.listdir('train')
print(train_labels)
print(len(train_labels))
# Out:
# ['Pikachu', 'Charmeleon', 'Rhydon', 'Victreebel', 'Charmander', 'Metapod', 'Sandshrew', 'Weepinbell', 'Venusaur', 'Zapdos', 'Machop', 'Electrode', 'Arbok', 'Slowpoke', 'Psyduck', 'Eevee', 'Weedle', 'Clefable', 'Rhyhorn', 'Magmar', 'MrMime', 'Magneton', 'Paras', 'Ivysaur', 'Hypno', 'Electabuzz', 'Vileplume', 'Seadra', 'Slowbro', 'Articuno', 'Primeape', 'Kabuto', 'Koffing', 'Flareon', 'Pidgeot', 'Kakuna', 'Blastoise', 'Magikarp', 'Mew', 'Staryu', 'Voltorb', 'Venonat', 'Tangela', 'Kingler', 'Poliwrath', 'Kadabra', 'Nidorina', 'Squirtle', 'Dratini', 'Vulpix', 'Shellder', 'Doduo', 'Porygon', 'Sandslash', 'Nidoking', 'Farfetchd', 'Parasect', 'Meowth', 'Wigglytuff', 'Lickitung', 'Machoke', 'Caterpie', 'Machamp', 'Pidgey', 'Goldeen', 'Arcanine', 'Gengar', 'Lapras', 'Exeggcute', 'Bulbasaur', 'Poliwag', 'Charizard', 'Beedrill', 'Exeggutor', 'Ponyta', 'Omastar', 'Tentacool', 'Drowzee', 'Ditto', 'Butterfree', 'Haunter', 'Dodrio', 'Starmie', 'Golbat', 'Cubone', 'Rattata', 'Diglett', 'Krabby', 'Dugtrio', 'Seel', 'Gastly', 'Persian', 'Magnemite', 'Pinsir', 'Tauros', 'Golem', 'Growlithe', 'Onix', 'Kangaskhan', 'Hitmonchan', 'Fearow', 'Aerodactyl', 'Weezing', 'Raichu', 'Muk', 'Dragonair', 'Geodude', 'Grimer', 'Abra', 'Oddish', 'Bellsprout', 'Wartortle', 'Dewgong', 'Jigglypuff', 'Gloom', 'Ekans', 'Ninetales', 'Pidgeotto', 'Nidoqueen', 'Graveler', 'Rapidash', 'Omanyte', 'Venomoth', 'Gyarados', 'Chansey', 'Horsea', 'Poliwhirl', 'Tentacruel', 'Raticate', 'Clefairy', 'Golduck', 'Jolteon', 'Zubat', 'Spearow', 'Nidorino', 'Moltres', 'Cloyster', 'Alakazam', 'Scyther', 'Dragonite', 'Hitmonlee', 'Seaking', 'Vaporeon', 'Snorlax', 'Jynx', 'Kabutops', 'Marowak', 'Mankey', 'Mewtwo']
# 149

# %%
value_labels = os.listdir('validation')
print(value_labels)
print(len(value_labels))
# Out:
# ['Pikachu', 'Mismagius', 'Bunnelby', 'Wailord', 'Gogoat', 'Charmeleon', 'Necrozma', 'Cramorant', 'Whiscash', 'Rhydon', 'Heatran', 'Blaziken', 'Coalossal', 'Vanillite', 'Gumshoos', 'Patrat', 'Fletchinder', 'Victreebel', 'Altaria', 'Drizzile', 'Grubbin', 'Donphan', 'Steenee', 'Cacnea', 'Doublade', 'Nickit', 'Terrakion', 'Foongus', 'Zekrom', 'Charmander', 'Helioptile', 'Whismur', 'Metapod', 'Sandshrew', 'Shroomish', 'Stoutland', 'Munna', 'Regieleki', 'Solosis', 'Aron', 'Mandibuzz', 'Spectrier', 'Remoraid', 'Weepinbell', 'Escavalier', 'Makuhita', 'Solrock', 'Venusaur', 'Zebstrika', 'Turtwig', 'Krookodile', 'Electrike', 'Crabrawler', 'Arceus', 'Kommo-o', 'Aurorus', 'Zapdos', 'Machop', 'Fennekin', 'Emolga', 'Houndour', 'Zangoose', 'Stakataka', 'Noivern', 'Comfey', 'Alomomola', 'Bibarel', 'Avalugg', 'Snom', 'Lombre', 'Beldum', 'Electrode', 'Arbok', 'Pichu', 'Cobalion', 'Oshawott', 'Yamask', 'Slowpoke', 'Malamar', 'Drifblim', 'Psyduck', 'Eevee', 'Frosmoth', 'Magmortar', 'Illumise', 'Weedle', 'Clefable', 'Wobbuffet', 'Ribombee', 'Pansear', 'Gallade', 'Skitty', 'Falinks', 'Beartic', 'Togepi', 'Skuntank', 'Arrokuda', 'Jangmo-o', 'Totodile', 'Ho-oh', 'Mawile', 'Croagunk', 'Tropius', 'Bruxish', 'Granbull', 'Minun', 'Mesprit', 'Swellow', 'Pikipek', 'NidoranтЩА', 'Beautifly', 'Braixen', 'Darmanitan', 'Feraligatr', 'Golett', 'Metagross', 'Nosepass', 'Girafarig', 'Heatmor', 'Mudsdale', 'Rhyhorn', 'Binacle', 'Greninja', 'Sobble', 'Corviknight', 'Magmar', 'Whirlipede', 'Mudbray', 'Combee', 'Vespiquen', 'Blipbug', 'Goomy', 'Marshtomp', 'Bronzor', 'Regigigas', 'Magneton', 'Paras', 'Gligar', 'Tepig', 'Seedot', 'Ivysaur', 'Hypno', 'Porygon2', 'Milotic', 'Keldeo', 'Crobat', 'Yanmega', 'Sealeo', 'Orbeetle', 'Shaymin', 'Uxie', 'Hoppip', 'Grovyle', 'Empoleon', 'Electabuzz', 'Watchog', 'Roggenrola', 'Barraskewda', 'Mienfoo', 'Vileplume', 'Floatzel', 'Drampa', 'Obstagoon', 'Leafeon', 'Eiscue', 'Unown', 'Runerigus', 'Stantler', 'Chikorita', 'Ducklett', 'Pawniard', 'Vibrava', 'Seadra', 'Zorua', 'Regidrago', 'Noibat', 'Tyrantrum', 'Slowbro', 'Larvesta', 'Zygarde', 'Tapu Fini', 'Swampert', 'Drakloak', 'Raikou', 'Oricorio', 'Articuno', 'Lairon', 'Passimian', 'Wooper', 'Cufant', 'Tranquill', 'Toucannon', 'Simisear', 'Electivire', 'Popplio', 'Vikavolt', 'Regice', 'Karrablast', 'Magcargo', 'Blissey', 'Primeape', 'Emboar', 'Duosion', 'Sceptile', 'Fraxure', 'Copperajah', 'Thwackey', 'Darkrai', 'Diancie', 'Goodra', 'Starly', 'Cascoon', 'Magearna', 'Dustox', 'Litten', 'Dialga', 'Kabuto', 'Honchkrow', 'Torkoal', 'Gabite', 'Rampardos', 'Koffing', 'Slurpuff', 'Zarude', 'Servine', 'Miltank', 'Zigzagoon', 'Relicanth', 'Cherubi', 'Gardevoir', 'Kricketune', 'Taillow', 'Milcery', 'Medicham', 'Rufflet', 'Flareon', 'Hatenna', 'Wooloo', 'Pidgeot', 'Slugma', 'Froslass', 'Kakuna', 'Sandaconda', 'Noctowl', 'Silcoon', 'Ursaring', 'Smeargle', 'Blastoise', 'Marill', 'Togedemaru', 'Houndoom', 'Wynaut', 'Magikarp', 'Baltoy', 'Manectric', 'Dartrix', 'Drapion', 'Bergmite', 'Virizion', 'Grapploct', 'Mew', 'Pincurchin', 'Staryu', 'Shiinotic', 'NidoranтЩВ', 'Glaceon', 'Togetic', 'Glameow', 'Gurdurr', 'Galvantula', 'Spritzee', 'Voltorb', 'Druddigon', 'Venonat', 'Tangela', 'Klink', 'Clawitzer', 'Pachirisu', 'Lopunny', 'Azurill', 'Torracat', 'Yamper', 'Golurk', 'Zweilous', 'Araquanid', 'Wailmer', 'Greedent', 'Natu', 'Forretress', 'Kingler', 'Cinderace', 'Corphish', 'Delphox', 'Floette', 'Eternatus', 'Lampent', 'Rookidee', 'Poliwrath', 'Fletchling', 'Sableye', 'Infernape', 'Kartana', 'Slowking', 'Kadabra', 'Drilbur', 'Durant', 'Roserade', 'Morelull', 'Nidorina', 'Meloetta', 'Squirtle', 'Croconaw', 'Riolu', 'Linoone', 'Flaaffy', 'Rhyperior', 'Kricketot', 'Shellos', 'Loudred', 'Diggersby', 'Genesect', 'Naganadel', 'Carkol', 'Monferno', 'Vanillish', 'Walrein', 'Dratini', 'Vulpix', 'Shellder', 'Meltan', 'Chesnaught', 'Qwilfish', 'Aegislash', 'Buneary', 'Tornadus', 'Snivy', 'Gigalith', 'Murkrow', 'Crustle', 'Doduo', 'Polteageist', 'Mimikyu', 'Inteleon', 'Toxicroak', 'Sinistea', 'Litwick', 'Porygon', ...
# 898

# %%
# shutil.rmtree(os.path.join('validation'))

# %%
# shutil.rmtree(os.path.join('train'))

# %%
# train: 149, validation: 898
# validation에서 train에 있는 디렉토리를 확인하여 없는 디렉토리를 모두 제거
import fnmatch
import shutil

# for value_name in value_labels:
#     del_ok = False
#     for train_name in train_labels:
#         if fnmatch.fnmatch(value_name, train_name):
#             del_ok = True
#             break
#     if not del_ok:
#         shutil.rmtree("validation/"+value_name)
# len(os.listdir('validation'))

for value_name in value_labels:
    if value_name not in train_labels:
        value_path = os.path.join('validation', value_name)
        shutil.rmtree(value_path)

# %%
for train_label in train_labels:
    if train_label not in value_labels:
        print(train_label)
        os.makedirs(os.path.join('validation', train_label), exist_ok=True)

# %%
for train_label in train_labels:
    if train_label not in value_labels:
        print(train_label)

# %%
value_labels = os.listdir('validation')
print(value_labels)
print(len(value_labels))
# Out:
# ['Pikachu', 'Charmeleon', 'Rhydon', 'Victreebel', 'Charmander', 'Metapod', 'Sandshrew', 'Weepinbell', 'Venusaur', 'Zapdos', 'Machop', 'Electrode', 'Arbok', 'Slowpoke', 'Psyduck', 'Eevee', 'Weedle', 'Clefable', 'Rhyhorn', 'Magmar', 'MrMime', 'Magneton', 'Paras', 'Ivysaur', 'Hypno', 'Electabuzz', 'Vileplume', 'Seadra', 'Slowbro', 'Articuno', 'Primeape', 'Kabuto', 'Koffing', 'Flareon', 'Pidgeot', 'Kakuna', 'Blastoise', 'Magikarp', 'Mew', 'Staryu', 'Voltorb', 'Venonat', 'Tangela', 'Kingler', 'Poliwrath', 'Kadabra', 'Nidorina', 'Squirtle', 'Dratini', 'Vulpix', 'Shellder', 'Doduo', 'Porygon', 'Sandslash', 'Nidoking', 'Farfetchd', 'Parasect', 'Meowth', 'Wigglytuff', 'Lickitung', 'Machoke', 'Caterpie', 'Machamp', 'Pidgey', 'Goldeen', 'Arcanine', 'Gengar', 'Lapras', 'Exeggcute', 'Bulbasaur', 'Poliwag', 'Charizard', 'Beedrill', 'Exeggutor', 'Ponyta', 'Omastar', 'Tentacool', 'Drowzee', 'Ditto', 'Butterfree', 'Haunter', 'Dodrio', 'Starmie', 'Golbat', 'Cubone', 'Rattata', 'Diglett', 'Krabby', 'Dugtrio', 'Seel', 'Gastly', 'Persian', 'Magnemite', 'Pinsir', 'Tauros', 'Golem', 'Growlithe', 'Onix', 'Kangaskhan', 'Hitmonchan', 'Fearow', 'Aerodactyl', 'Weezing', 'Raichu', 'Muk', 'Dragonair', 'Geodude', 'Grimer', 'Abra', 'Oddish', 'Bellsprout', 'Wartortle', 'Dewgong', 'Jigglypuff', 'Gloom', 'Ekans', 'Ninetales', 'Pidgeotto', 'Nidoqueen', 'Graveler', 'Rapidash', 'Omanyte', 'Venomoth', 'Gyarados', 'Chansey', 'Horsea', 'Poliwhirl', 'Tentacruel', 'Raticate', 'Clefairy', 'Golduck', 'Jolteon', 'Zubat', 'Spearow', 'Nidorino', 'Moltres', 'Cloyster', 'Alakazam', 'Scyther', 'Dragonite', 'Hitmonlee', 'Seaking', 'Vaporeon', 'Snorlax', 'Jynx', 'Kabutops', 'Marowak', 'Mankey', 'Mewtwo']
# 149

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
from torchvision import datasets, models, transforms
from torch.utils.data import DataLoader

device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)

data_transforms = {
    'train': transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.RandomAffine(0, shear=10, scale=(0.8, 1.2)),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor()
    ]),
    'validation': transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor()
    ])
}




image_datasets = {
    'train': datasets.ImageFolder('train', data_transforms['train']),
    'validation': datasets.ImageFolder('validation', data_transforms['validation'])
}

dataloaders = {
    'train': DataLoader(
        image_datasets['train'],
        batch_size=32,
        shuffle=True
    ),
    'validation': DataLoader(
        image_datasets['validation'],
        batch_size=32,
        shuffle=False
    )
}

print(len(image_datasets['train']), len(image_datasets['validation']))

imgs, labels = next(iter(dataloaders['train']))
fig, axes = plt.subplots(4, 8, figsize=(20, 10))

for img, label, ax in zip(imgs, labels, axes.flatten()):
    ax.set_title(label)
    ax.imshow(img.permute(1, 2, 0))
    ax.axis('off')
# Out:
# cuda
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-22-57b7e9767853> in <cell line: 25>()
#      24 image_datasets = {
#      25     'train': datasets.ImageFolder('train', data_transforms['train']),
# ---> 26     'validation': datasets.ImageFolder('validation', data_transforms['validation'])
#      27 }
#      28
#
# /usr/local/lib/python3.10/dist-packages/torchvision/datasets/folder.py in __init__(self, root, transform, target_transform, loader, is_valid_file)
#     307         is_valid_file: Optional[Callable[[str], bool]] = None,
#     308     ):
# --> 309         super().__init__(
#     310             root,
#     311             loader,
#
# /usr/local/lib/python3.10/dist-packages/torchvision/datasets/folder.py in __init__(self, root, loader, extensions, transform, target_transform, is_valid_file)
#     143         super().__init__(root, transform=transform, target_transform=target_transform)
#     144         classes, class_to_idx = self.find_classes(self.root)
# --> 145         samples = self.make_dataset(self.root, class_to_idx, extensions, is_valid_file)
#     146
#     147         self.loader = loader
#
# /usr/local/lib/python3.10/dist-packages/torchvision/datasets/folder.py in make_dataset(directory, class_to_idx, extensions, is_valid_file)
#     187             # is potentially overridden and thus could have a different logic.
#     188             raise ValueError("The class_to_idx parameter cannot be None.")
# --> 189         return make_dataset(directory, class_to_idx, extensions=extensions, is_valid_file=is_valid_file)
#     190
#     191     def find_classes(self, directory: str) -> Tuple[List[str], Dict[str, int]]:
#
# /usr/local/lib/python3.10/dist-packages/torchvision/datasets/folder.py in make_dataset(directory, class_to_idx, extensions, is_valid_file)
#     100         if extensions is not None:
#     101             msg += f"Supported extensions are: {extensions if isinstance(extensions, str) else ', '.join(extensions)}"
# --> 102         raise FileNotFoundError(msg)
#     103
#     104     return instances
#
# FileNotFoundError: Found no valid file for the classes Farfetchd, MrMime. Supported extensions are: .jpg, .jpeg, .png, .ppm, .bmp, .pgm, .tif, .tiff, .webp

# %%
print(image_datasets['train'].classes[101])

# %%
from torchvision.models import efficientnet_b4, EfficientNet_B4_Weights
from torchvision.models._api import WeightsEnum
from torch.hub import load_state_dict_from_url

def get_state_dict(self, *args, **kwargs):
    kwargs.pop("check_hash")
    return load_state_dict_from_url(self.url, *args, **kwargs)

WeightsEnum.get_state_dict = get_state_dict

# 트러블슈팅하기

# %%
efficientnet_b4(weights=EfficientNet_B4_Weights.IMAGENET1K_V1)
model = efficientnet_b4(weights="DEFAULT")
model1 = efficientnet_b4(weights="DEFAULT")

# %%
print(model.classifier, model1.classifier)

# %%
# FC Layer 수정
# print(model)
for param in model.parameters():
    param.requires_grad = False # 가져온 파라미터 (W, b)를 업데이트하지 않음
# 149

model.classifier = nn.Sequential(
    nn.Linear(1792, 512),
    nn.ReLU(),
    nn.Linear(512, 149)
)

model = model.to(device)
model1 = model1.to(device)
# print(model)

# %%
print(model.classifier, model1.classifier)

# %%
# 학습
# optimizer: Adam
# epochs: 10
optimizer = optim.Adam(model.classifier.parameters(), lr=0.001)
# optimizer = optim.Adam(model.parameters(), lr=0.001) # fc 파라미터와 다름

epochs = 10

for epoch in range(epochs+1):
    for phase in ['train', 'validation']:
        if phase == 'train':
            model.train()
        else:
            model.eval()

        sum_loss = 0
        sum_acc = 0

        for x_batch, y_batch in dataloaders[phase]:
            x_batch, y_batch = x_batch.to(device), y_batch.to(device)

            y_pred = model(x_batch)
            loss = nn.CrossEntropyLoss()(y_pred, y_batch)

            if phase == 'train':
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

            sum_loss = sum_loss + loss.item()

            y_prob = nn.Softmax(1)(y_pred)

            y_pred_index = torch.argmax(y_prob, axis=1)

            accuracy = (y_batch == y_pred_index).float().sum() / len(y_batch) * 100
            sum_acc = sum_acc + accuracy

        avg_loss = sum_loss / len(dataloaders[phase])
        avg_acc = sum_acc / len(dataloaders[phase])

        print(f'{phase:10s}: Epoch {epoch:4d}/{epochs} Loss: {avg_loss:.6f} Accuracy: {avg_acc:.2f}%')

# %%
# 이미지를 validation에서 선택하여 분류가 잘 되는지 확인하기

pred = model()

# %%
# 학습된 모델 파일 저장
torch.save(model.state_dict(), 'model.pth') # model.h5

# %%
model = models.efficient_b4().to(device)

model.classifier = nn.Sequential(
    nn.Linear(1792, 512),
    nn.ReLU(),
    nn.Linear(512, 149)
).to(device)

print(model)

# %%
model.load_state_dict(torch.load('model.pth'))
model.eval()

# %%
from PIL import Image

img1 = Image.open('/content/validation/Ditto/0.jpg')
img2 = Image.open('/content/validation/Charmander')

fig, axes = plt.subplots(1,2, figsize=(12,6))
axes[0].imshow(img1)
axes[0].axis('off')
axes[1].imshow(img2)
axes[1].axis('off')
plt.show()

# %%
img1_input = data_transforms['validation'](img1)
img2_input = data_transforms['validation'](img2)
print(img1_input.shape)
print(img2_input.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-f435e92f1ae2> in <cell line: 1>()
# ----> 1 img1_input = data_transforms['validation'](img1)
#       2 img2_input = data_transforms['validation'](img2)
#       3 print(img1_input.shape)
#       4 print(img2_input.shape)
#
# NameError: name 'img1' is not defined

# %%
test_batch = torch.stack([img1_input, img2_input])
test_batch = test_batch.to(device)
test_batch.shape

# %%
y_pred = model(test_batch)
y_pred
