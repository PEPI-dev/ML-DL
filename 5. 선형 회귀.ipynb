# %% [markdown]
# # 1. Rent 데이터셋

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
rent_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/머신러닝과 딥러닝/data/rent.csv')
rent_df
# Out:
#        Posted On  BHK   Rent    Size            Floor    Area Type  \
# 0     2022-05-18  2.0  10000  1100.0  Ground out of 2   Super Area
# 1     2022-05-13  2.0  20000   800.0       1 out of 3   Super Area
# 2     2022-05-16  2.0  17000  1000.0       1 out of 3   Super Area
# 3     2022-07-04  NaN  10000   800.0       1 out of 2   Super Area
# 4     2022-05-09  2.0   7500   850.0       1 out of 2  Carpet Area
# ...          ...  ...    ...     ...              ...          ...
# 4741  2022-05-18  2.0  15000  1000.0       3 out of 5  Carpet Area
# 4742  2022-05-15  3.0  29000  2000.0       1 out of 4   Super Area
# 4743  2022-07-10  3.0  35000  1750.0       3 out of 5  Carpet Area
# 4744  2022-07-06  3.0  45000  1500.0     23 out of 34  Carpet Area
# 4745  2022-05-04  2.0  15000  1000.0       4 out of 5  Carpet Area
#
#                  Area Locality       City Furnishing Status  Tenant Preferred  \
# 0                       Bandel    Kolkata       Unfurnished  Bachelors/Family
# ...

# %%
rent_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4746 entries, 0 to 4745
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Posted On          4746 non-null   object
#  1   BHK                4743 non-null   float64
#  2   Rent               4746 non-null   int64
#  3   Size               4741 non-null   float64
#  4   Floor              4746 non-null   object
#  5   Area Type          4746 non-null   object
#  6   Area Locality      4746 non-null   object
#  7   City               4746 non-null   object
#  8   Furnishing Status  4746 non-null   object
#  9   Tenant Preferred   4746 non-null   object
#  10  Bathroom           4746 non-null   int64
#  11  Point of Contact   4746 non-null   object
# dtypes: float64(2), int64(2), object(8)
# memory usage: 445.1+ KB

# %% [markdown]
# * Posted On: 매물 등록 날짜
# * BHK: 베드, 홀, 키친의 개수
# * Rent: 렌트비
# * Size: 집 크키
# * Floor: 총 층수 중 몇 층
# * Area Type: 공용공간을 포함하는지, 집의 면적만 포함하는지
# * Area Locality: 지역
# * City: 도시
# * Furnishing Status: 풀옵션 여부
# * Tenant Preferred: 선호하는 가족 형태
# * Bathroom: 화장실 개수
# * Point of Contact: 연락할 곳

# %%
rent_df.describe()
# Out:
#                BHK          Rent         Size     Bathroom
# count  4743.000000  4.746000e+03  4741.000000  4746.000000
# mean      2.083913  3.499345e+04   967.477536     1.965866
# std       0.832516  7.810641e+04   634.532781     0.884532
# min       1.000000  1.200000e+03    10.000000     1.000000
# 25%       2.000000  1.000000e+04   550.000000     1.000000
# 50%       2.000000  1.600000e+04   850.000000     2.000000
# 75%       3.000000  3.300000e+04  1200.000000     2.000000
# max       6.000000  3.500000e+06  8000.000000    10.000000

# %%
4.746000e+03
# Out:
# 4746.0

# %%
round(rent_df.describe(), 2) # 2: 소수점 둘째자리까지 표시
# Out:
#            BHK        Rent     Size  Bathroom
# count  4743.00     4746.00  4741.00   4746.00
# mean      2.08    34993.45   967.48      1.97
# std       0.83    78106.41   634.53      0.88
# min       1.00     1200.00    10.00      1.00
# 25%       2.00    10000.00   550.00      1.00
# 50%       2.00    16000.00   850.00      2.00
# 75%       3.00    33000.00  1200.00      2.00
# max       6.00  3500000.00  8000.00     10.00

# %%
rent_df['BHK']
# Out:
# 0       2.0
# 1       2.0
# 2       2.0
# 3       NaN
# 4       2.0
#        ...
# 4741    2.0
# 4742    3.0
# 4743    3.0
# 4744    3.0
# 4745    2.0
# Name: BHK, Length: 4746, dtype: float64

# %%
sns.displot(rent_df['BHK'])

# %%
sns.displot(rent_df['Rent']) # 렌트비는

# %%
rent_df['Rent'].sort_values()
# Out:
# 4076       1200
# 285        1500
# 471        1800
# 2475       2000
# 146        2200
#          ...
# 1459     700000
# 1329     850000
# 827     1000000
# 1001    1200000
# 1837    3500000
# Name: Rent, Length: 4746, dtype: int64

# %%
sns.boxplot(y=rent_df['Rent'])
# Out:
# <Axes: ylabel='Rent'>

# %%
sns.boxplot(y=rent_df['BHK'])
# Out:
# <Axes: ylabel='BHK'>

# %%
rent_df.isna

# %%
rent_df.dropna(subset=['BHK'])
# Out:
#        Posted On  BHK   Rent    Size            Floor    Area Type  \
# 0     2022-05-18  2.0  10000  1100.0  Ground out of 2   Super Area
# 1     2022-05-13  2.0  20000   800.0       1 out of 3   Super Area
# 2     2022-05-16  2.0  17000  1000.0       1 out of 3   Super Area
# 4     2022-05-09  2.0   7500   850.0       1 out of 2  Carpet Area
# 5     2022-04-29  2.0   7000   600.0  Ground out of 1   Super Area
# ...          ...  ...    ...     ...              ...          ...
# 4741  2022-05-18  2.0  15000  1000.0       3 out of 5  Carpet Area
# 4742  2022-05-15  3.0  29000  2000.0       1 out of 4   Super Area
# 4743  2022-07-10  3.0  35000  1750.0       3 out of 5  Carpet Area
# 4744  2022-07-06  3.0  45000  1500.0     23 out of 34  Carpet Area
# 4745  2022-05-04  2.0  15000  1000.0       4 out of 5  Carpet Area
#
#                  Area Locality       City Furnishing Status  Tenant Preferred  \
# 0                       Bandel    Kolkata       Unfurnished  Bachelors/Family
# ...

# %%
# rent_df 에서 Size가 NaN인 데이터의 index 저장

na_index = rent_df[rent_df['Size'].isna()].index
na_index
# Out:
# Int64Index([425, 430, 4703, 4731, 4732], dtype='int64')

# %%
rent_df['BHK'].fillna(rent_df['BHK'].median()).loc(na_index)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2daafd3f6aa8> in <cell line: 1>()
# ----> 1 rent_df['BHK'].fillna(rent_df['BHK'].median()).loc(na_index)
#
# NameError: name 'rent_df' is not defined

# %%
rent_df.isna().mean()
# Out:
# Posted On            0.000000
# BHK                  0.000632
# Rent                 0.000000
# Size                 0.001054
# Floor                0.000000
# Area Type            0.000000
# Area Locality        0.000000
# City                 0.000000
# Furnishing Status    0.000000
# Tenant Preferred     0.000000
# Bathroom             0.000000
# Point of Contact     0.000000
# dtype: float64

# %%
rent_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4746 entries, 0 to 4745
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Posted On          4746 non-null   object
#  1   BHK                4743 non-null   float64
#  2   Rent               4746 non-null   int64
#  3   Size               4741 non-null   float64
#  4   Floor              4746 non-null   object
#  5   Area Type          4746 non-null   object
#  6   Area Locality      4746 non-null   object
#  7   City               4746 non-null   object
#  8   Furnishing Status  4746 non-null   object
#  9   Tenant Preferred   4746 non-null   object
#  10  Bathroom           4746 non-null   int64
#  11  Point of Contact   4746 non-null   object
# dtypes: float64(2), int64(2), object(8)
# memory usage: 445.1+ KB

# %%
rent_df['Area Type'].value_counts()
# Out:
# Super Area     2446
# Carpet Area    2298
# Built Area        2
# Name: Area Type, dtype: int64

# %%
rent_df['Area Type'].unique()
# Out:
# array(['Super Area', 'Carpet Area', 'Built Area'], dtype=object)

# %%
rent_df['Area Type'].nunique()
# Out:
# 3

# %%
# 유니크한 종류의 개수 출력
# Fllor, Area Type, Area Locality, Pusishing statement
df_= [Fllor]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-7c4222b8d225> in <cell line: 3>()
#       1 # 유니크한 종류의 개수 출력
#       2 # Fllor, Area Type, Area Locality, Pusishing statement
# ----> 3 df_= [Fllor]
#
# NameError: name 'Fllor' is not defined

# %%
x = rent_df.drop('Rent)')

# %% [markdown]
# # 선형 회귀(Linear Regression)
# - 데이터를 통해 가장 잘 설명할 수 있는 직선으로 데이터 분석한느 방법
#   - 단순 성형 회귀분석(단일 독립변수를 이용)
#   - 다중 선형 회귀분석(다중 독립변수 이용)
